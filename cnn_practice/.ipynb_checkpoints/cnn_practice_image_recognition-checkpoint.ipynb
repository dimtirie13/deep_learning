# %%
import keras
from keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
# visualize a small subset of images

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(X_train[i]))

# %%
# rescacle images

X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(X_train, X_valid) = X_train[5000:], X_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training sets
print('X_train Shape:', X_train.shape)

# print the number of training, validation and test images
print(X_train.shape[0], 'train samples')
print(X_valid.shape[0], 'validation samples')
print(y_train.shape[0], 'test samples')
# Out:
# X_train Shape: (45000, 32, 32, 3)
# 45000 train samples
# 5000 validation samples
# 45000 test samples

# %%
# train first model: Regular Neural Network
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten

# define model
model = Sequential()
model.add(Flatten(input_shape=X_train.shape[1:]))
model.add(Dense(1000, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1000)              3073000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,590,642
# Trainable params: 3,590,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
#train the model

from keras.callbacks import ModelCheckpoint

checkpointer = ModelCheckpoint(filepath='MLP.weights.best.hdf5', verbose=1, save_best_only = True)
hist= model.fit(X_train, y_train, batch_size=32, epochs=20, validation_data=(X_valid, y_valid), callbacks=[checkpointer],verbose=2, shuffle=True)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
#  - 127s - loss: 2.3169 - acc: 0.2672 - val_loss: 2.0713 - val_acc: 0.2630
#
# Epoch 00001: val_loss improved from inf to 2.07134, saving model to MLP.weights.best.hdf5
# Epoch 2/20
#  - 134s - loss: 1.8495 - acc: 0.3316 - val_loss: 1.7102 - val_acc: 0.3914
#
# Epoch 00002: val_loss improved from 2.07134 to 1.71025, saving model to MLP.weights.best.hdf5
# Epoch 3/20
#  - 130s - loss: 1.8018 - acc: 0.3535 - val_loss: 1.7749 - val_acc: 0.3480
#
# Epoch 00003: val_loss did not improve from 1.71025
# Epoch 4/20
#  - 132s - loss: 1.7826 - acc: 0.3644 - val_loss: 1.8588 - val_acc: 0.3242
#
# Epoch 00004: val_loss did not improve from 1.71025
# Epoch 5/20
#  - 119s - loss: 1.7647 - acc: 0.3738 - val_loss: 1.7993 - val_acc: 0.3534
#
# Epoch 00005: val_loss did not improve from 1.71025
# Epoch 6/20
#  - 73s - loss: 1.7591 - acc: 0.3760 - val_loss: 1.6603 - val_acc: 0.4098
#
# Epoch 00006: val_loss improved from 1.71025 to 1.66026, saving model to MLP.weights.best.hdf5
# Epoch 7/20
#  - 85s - loss: 1.7547 - acc: 0.3787 - val_loss: 1.6597 - val_acc: 0.4076
#
# Epoch 00007: val_loss improved from 1.66026 to 1.65973, saving model to MLP.weights.best.hdf5
# Epoch 8/20
#  - 134s - loss: 1.7518 - acc: 0.3810 - val_loss: 1.7665 - val_acc: 0.3580
#
# Epoch 00008: val_loss did not improve from 1.65973
# Epoch 9/20
#  - 129s - loss: 1.7523 - acc: 0.3816 - val_loss: 1.7914 - val_acc: 0.3636
#
# Epoch 00009: val_loss did not improve from 1.65973
# Epoch 10/20
#  - 73s - loss: 1.7665 - acc: 0.3751 - val_loss: 1.6870 - val_acc: 0.3898
#
# Epoch 00010: val_loss did not improve from 1.65973
# Epoch 11/20
#  - 66s - loss: 1.7643 - acc: 0.3787 - val_loss: 1.6777 - val_acc: 0.4126
#
# Epoch 00011: val_loss did not improve from 1.65973
# Epoch 12/20
#  - 64s - loss: 1.7681 - acc: 0.3766 - val_loss: 1.7342 - val_acc: 0.3918
#
# Epoch 00012: val_loss did not improve from 1.65973
# Epoch 13/20
#  - 64s - loss: 1.7695 - acc: 0.3749 - val_loss: 2.4051 - val_acc: 0.2674
#
# Epoch 00013: val_loss did not improve from 1.65973
# Epoch 14/20
#  - 66s - loss: 1.7728 - acc: 0.3767 - val_loss: 1.6784 - val_acc: 0.3992
#
# Epoch 00014: val_loss did not improve from 1.65973
# Epoch 15/20
#  - 66s - loss: 1.7689 - acc: 0.3763 - val_loss: 1.7473 - val_acc: 0.3712
#
# Epoch 00015: val_loss did not improve from 1.65973
# Epoch 16/20
#  - 64s - loss: 1.7711 - acc: 0.3775 - val_loss: 1.7069 - val_acc: 0.4054
#
# Epoch 00016: val_loss did not improve from 1.65973
# Epoch 17/20
#  - 65s - loss: 1.7841 - acc: 0.3731 - val_loss: 1.8226 - val_acc: 0.3586
#
# Epoch 00017: val_loss did not improve from 1.65973
# Epoch 18/20
#  - 64s - loss: 1.7804 - acc: 0.3727 - val_loss: 1.7585 - val_acc: 0.3730
#
# Epoch 00018: val_loss did not improve from 1.65973
# Epoch 19/20
#  - 63s - loss: 1.7839 - acc: 0.3758 - val_loss: 1.7277 - val_acc: 0.3796
#
# Epoch 00019: val_loss did not improve from 1.65973
# Epoch 20/20
#  - 67s - loss: 1.7821 - acc: 0.3717 - val_loss: 1.8896 - val_acc: 0.3488
#
# Epoch 00020: val_loss did not improve from 1.65973

# %%
model.load_weights('MLP.weights.best.hdf5')

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('\n', 'Test Accuracy:', score[1])
# Out:
#  Test Accuracy: 0.4173

# %% [markdown]
# ### Train a CNN for the same problem

# %%
# Define CNN architecture
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Convolution2D, MaxPool2D

# define model
model = Sequential()
model.add(Convolution2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=(32,32,3)))
model.add(MaxPool2D(pool_size=2))
model.add(Convolution2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=2))
model.add(Convolution2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))


model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 500)               512500
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile cnn
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
# Train cnn
#train the model

from keras.callbacks import ModelCheckpoint

checkpointer = ModelCheckpoint(filepath='CNN.weights.best.hdf5', verbose=1, save_best_only = True)
hist= model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_valid, y_valid), callbacks=[checkpointer],verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 47s - loss: 1.5640 - acc: 0.4326 - val_loss: 1.5091 - val_acc: 0.4798
#
# Epoch 00001: val_loss improved from inf to 1.50913, saving model to CNN.weights.best.hdf5
# Epoch 2/100
#  - 44s - loss: 1.2414 - acc: 0.5578 - val_loss: 1.4270 - val_acc: 0.5140
#
# Epoch 00002: val_loss improved from 1.50913 to 1.42700, saving model to CNN.weights.best.hdf5
# Epoch 3/100
#  - 43s - loss: 1.1240 - acc: 0.6024 - val_loss: 1.1484 - val_acc: 0.5870
#
# Epoch 00003: val_loss improved from 1.42700 to 1.14840, saving model to CNN.weights.best.hdf5
# Epoch 4/100
#  - 45s - loss: 1.0690 - acc: 0.6272 - val_loss: 1.0025 - val_acc: 0.6554
#
# Epoch 00004: val_loss improved from 1.14840 to 1.00250, saving model to CNN.weights.best.hdf5
# Epoch 5/100
#  - 44s - loss: 1.0283 - acc: 0.6410 - val_loss: 0.9245 - val_acc: 0.6928
#
# Epoch 00005: val_loss improved from 1.00250 to 0.92450, saving model to CNN.weights.best.hdf5
# Epoch 6/100
#  - 43s - loss: 1.0022 - acc: 0.6534 - val_loss: 1.0067 - val_acc: 0.6524
#
# Epoch 00006: val_loss did not improve from 0.92450
# Epoch 7/100
#  - 44s - loss: 0.9935 - acc: 0.6614 - val_loss: 0.9218 - val_acc: 0.6954
#
# Epoch 00007: val_loss improved from 0.92450 to 0.92183, saving model to CNN.weights.best.hdf5
# Epoch 8/100
#  - 45s - loss: 0.9854 - acc: 0.6638 - val_loss: 0.9608 - val_acc: 0.6844
#
# Epoch 00008: val_loss did not improve from 0.92183
# Epoch 9/100
#  - 50s - loss: 0.9783 - acc: 0.6667 - val_loss: 1.0010 - val_acc: 0.6648
#
# Epoch 00009: val_loss did not improve from 0.92183
# Epoch 10/100
#  - 60s - loss: 0.9926 - acc: 0.6639 - val_loss: 1.1351 - val_acc: 0.6354
#
# Epoch 00010: val_loss did not improve from 0.92183
# Epoch 11/100
#  - 49s - loss: 1.0069 - acc: 0.6614 - val_loss: 0.9902 - val_acc: 0.6570
#
# Epoch 00011: val_loss did not improve from 0.92183
# Epoch 12/100
#  - 46s - loss: 1.0161 - acc: 0.6606 - val_loss: 1.3118 - val_acc: 0.6108
#
# Epoch 00012: val_loss did not improve from 0.92183
# Epoch 13/100
#  - 49s - loss: 1.0330 - acc: 0.6567 - val_loss: 1.0576 - val_acc: 0.6648
#
# Epoch 00013: val_loss did not improve from 0.92183
# Epoch 14/100
#  - 47s - loss: 1.0583 - acc: 0.6497 - val_loss: 1.0655 - val_acc: 0.6716
#
# Epoch 00014: val_loss did not improve from 0.92183
# Epoch 15/100
#  - 45s - loss: 1.0705 - acc: 0.6469 - val_loss: 1.1691 - val_acc: 0.6358
#
# Epoch 00015: val_loss did not improve from 0.92183
# Epoch 16/100
#  - 46s - loss: 1.0917 - acc: 0.6405 - val_loss: 1.0853 - val_acc: 0.6408
#
# Epoch 00016: val_loss did not improve from 0.92183
# Epoch 17/100
#  - 46s - loss: 1.0990 - acc: 0.6367 - val_loss: 1.2681 - val_acc: 0.6320
#
# Epoch 00017: val_loss did not improve from 0.92183
# Epoch 18/100
#  - 48s - loss: 1.1141 - acc: 0.6329 - val_loss: 1.0472 - val_acc: 0.6544
#
# Epoch 00018: val_loss did not improve from 0.92183
# Epoch 19/100
#  - 49s - loss: 1.1433 - acc: 0.6230 - val_loss: 0.9564 - val_acc: 0.6832
#
# Epoch 00019: val_loss did not improve from 0.92183
# Epoch 20/100
#  - 51s - loss: 1.1440 - acc: 0.6242 - val_loss: 1.4731 - val_acc: 0.5874
#
# Epoch 00020: val_loss did not improve from 0.92183
# Epoch 21/100
#  - 46s - loss: 1.1663 - acc: 0.6202 - val_loss: 1.1038 - val_acc: 0.6298
#
# Epoch 00021: val_loss did not improve from 0.92183
# Epoch 22/100
#  - 47s - loss: 1.1901 - acc: 0.6083 - val_loss: 1.4587 - val_acc: 0.5050
#
# Epoch 00022: val_loss did not improve from 0.92183
# Epoch 23/100
#  - 49s - loss: 1.1957 - acc: 0.6089 - val_loss: 1.2232 - val_acc: 0.5946
#
# Epoch 00023: val_loss did not improve from 0.92183
# Epoch 24/100
#  - 48s - loss: 1.2197 - acc: 0.6004 - val_loss: 1.1548 - val_acc: 0.6204
#
# Epoch 00024: val_loss did not improve from 0.92183
# Epoch 25/100
#  - 47s - loss: 1.2338 - acc: 0.5976 - val_loss: 1.6818 - val_acc: 0.5712
#
# Epoch 00025: val_loss did not improve from 0.92183
# Epoch 26/100
#  - 46s - loss: 1.2591 - acc: 0.5884 - val_loss: 1.7762 - val_acc: 0.5186
#
# Epoch 00026: val_loss did not improve from 0.92183
# Epoch 27/100
#  - 46s - loss: 1.2729 - acc: 0.5835 - val_loss: 1.3707 - val_acc: 0.5454
#
# Epoch 00027: val_loss did not improve from 0.92183
# Epoch 28/100
#  - 46s - loss: 1.2792 - acc: 0.5768 - val_loss: 1.2960 - val_acc: 0.5562
#
# Epoch 00028: val_loss did not improve from 0.92183
# Epoch 29/100
#  - 49s - loss: 1.3015 - acc: 0.5742 - val_loss: 1.0713 - val_acc: 0.6432
#
# Epoch 00029: val_loss did not improve from 0.92183
# Epoch 30/100
#  - 49s - loss: 1.3096 - acc: 0.5666 - val_loss: 1.2840 - val_acc: 0.5558
#
# Epoch 00030: val_loss did not improve from 0.92183
# Epoch 31/100
#  - 45s - loss: 1.3296 - acc: 0.5612 - val_loss: 1.5615 - val_acc: 0.5448
#
# Epoch 00031: val_loss did not improve from 0.92183
# Epoch 32/100
#  - 46s - loss: 1.3501 - acc: 0.5573 - val_loss: 2.4297 - val_acc: 0.5296
#
# Epoch 00032: val_loss did not improve from 0.92183
# Epoch 33/100
#  - 49s - loss: 1.3743 - acc: 0.5502 - val_loss: 1.5144 - val_acc: 0.5404
#
# Epoch 00033: val_loss did not improve from 0.92183
# Epoch 34/100
#  - 54s - loss: 1.3687 - acc: 0.5487 - val_loss: 1.5927 - val_acc: 0.5400
#
# Epoch 00034: val_loss did not improve from 0.92183
# Epoch 35/100
#  - 47s - loss: 1.4050 - acc: 0.5381 - val_loss: 1.2542 - val_acc: 0.5752
#
# Epoch 00035: val_loss did not improve from 0.92183
# Epoch 36/100
#  - 48s - loss: 1.4015 - acc: 0.5368 - val_loss: 1.2988 - val_acc: 0.5924
#
# Epoch 00036: val_loss did not improve from 0.92183
# Epoch 37/100
#  - 46s - loss: 1.4148 - acc: 0.5320 - val_loss: 1.1979 - val_acc: 0.5908
#
# Epoch 00037: val_loss did not improve from 0.92183
# Epoch 38/100
#  - 45s - loss: 1.4252 - acc: 0.5280 - val_loss: 1.1733 - val_acc: 0.6212
#
# Epoch 00038: val_loss did not improve from 0.92183
# Epoch 39/100
#  - 48s - loss: 1.4356 - acc: 0.5278 - val_loss: 1.3248 - val_acc: 0.5312
#
# Epoch 00039: val_loss did not improve from 0.92183
# Epoch 40/100
#  - 47s - loss: 1.4504 - acc: 0.5181 - val_loss: 1.2359 - val_acc: 0.5900
#
# Epoch 00040: val_loss did not improve from 0.92183
# Epoch 41/100
#  - 47s - loss: 1.4473 - acc: 0.5194 - val_loss: 1.2146 - val_acc: 0.5930
#
# Epoch 00041: val_loss did not improve from 0.92183
# Epoch 42/100
#  - 47s - loss: 1.4575 - acc: 0.5169 - val_loss: 1.5498 - val_acc: 0.5566
#
# Epoch 00042: val_loss did not improve from 0.92183
# Epoch 43/100
#  - 50s - loss: 1.4488 - acc: 0.5166 - val_loss: 1.6753 - val_acc: 0.4718
#
# Epoch 00043: val_loss did not improve from 0.92183
# Epoch 44/100
#  - 47s - loss: 1.4492 - acc: 0.5160 - val_loss: 1.5865 - val_acc: 0.4042
#
# Epoch 00044: val_loss did not improve from 0.92183
# Epoch 45/100
#  - 47s - loss: 1.4766 - acc: 0.5075 - val_loss: 1.6470 - val_acc: 0.5200
#
# Epoch 00045: val_loss did not improve from 0.92183
# Epoch 46/100
#  - 47s - loss: 1.4933 - acc: 0.5009 - val_loss: 1.5920 - val_acc: 0.4360
#
# Epoch 00046: val_loss did not improve from 0.92183
# Epoch 47/100
#  - 46s - loss: 1.4952 - acc: 0.4980 - val_loss: 1.4949 - val_acc: 0.4906
#
# Epoch 00047: val_loss did not improve from 0.92183
# Epoch 48/100
#  - 48s - loss: 1.4997 - acc: 0.4989 - val_loss: 1.2232 - val_acc: 0.5900
#
# Epoch 00048: val_loss did not improve from 0.92183
# Epoch 49/100
#  - 46s - loss: 1.5151 - acc: 0.4948 - val_loss: 1.4270 - val_acc: 0.5418
#
# Epoch 00049: val_loss did not improve from 0.92183
# Epoch 50/100
#  - 48s - loss: 1.5019 - acc: 0.4982 - val_loss: 1.4290 - val_acc: 0.5548
#
# Epoch 00050: val_loss did not improve from 0.92183
# Epoch 51/100
#  - 47s - loss: 1.5022 - acc: 0.4927 - val_loss: 2.3140 - val_acc: 0.4924
#
# Epoch 00051: val_loss did not improve from 0.92183
# Epoch 52/100
#  - 45s - loss: 1.5181 - acc: 0.4910 - val_loss: 1.3250 - val_acc: 0.5326
#
# Epoch 00052: val_loss did not improve from 0.92183
# Epoch 53/100
#  - 45s - loss: 1.5245 - acc: 0.4886 - val_loss: 1.5343 - val_acc: 0.5028
#
# Epoch 00053: val_loss did not improve from 0.92183
# Epoch 54/100
#  - 48s - loss: 1.5387 - acc: 0.4868 - val_loss: 1.5719 - val_acc: 0.4474
#
# Epoch 00054: val_loss did not improve from 0.92183
# Epoch 55/100
#  - 47s - loss: 1.5471 - acc: 0.4804 - val_loss: 2.1297 - val_acc: 0.3452
#
# Epoch 00055: val_loss did not improve from 0.92183
# Epoch 56/100
#  - 49s - loss: 1.5596 - acc: 0.4758 - val_loss: 1.5837 - val_acc: 0.5086
#
# Epoch 00056: val_loss did not improve from 0.92183
# Epoch 57/100
#  - 45s - loss: 1.5696 - acc: 0.4730 - val_loss: 1.5143 - val_acc: 0.5258
#
# Epoch 00057: val_loss did not improve from 0.92183
# Epoch 58/100
#  - 44s - loss: 1.5694 - acc: 0.4692 - val_loss: 1.3992 - val_acc: 0.5442
#
# Epoch 00058: val_loss did not improve from 0.92183
# Epoch 59/100
#  - 46s - loss: 1.5747 - acc: 0.4695 - val_loss: 1.2991 - val_acc: 0.5540
#
# Epoch 00059: val_loss did not improve from 0.92183
# Epoch 60/100
#  - 46s - loss: 1.5821 - acc: 0.4695 - val_loss: 1.4620 - val_acc: 0.5134
#
# Epoch 00060: val_loss did not improve from 0.92183
# Epoch 61/100
#  - 46s - loss: 1.5943 - acc: 0.4630 - val_loss: 1.4911 - val_acc: 0.4860
#
# Epoch 00061: val_loss did not improve from 0.92183
# Epoch 62/100
#  - 46s - loss: 1.6016 - acc: 0.4603 - val_loss: 1.3091 - val_acc: 0.5266
#
# Epoch 00062: val_loss did not improve from 0.92183
# Epoch 63/100
#  - 47s - loss: 1.6301 - acc: 0.4514 - val_loss: 1.6375 - val_acc: 0.3756
#
# Epoch 00063: val_loss did not improve from 0.92183
# Epoch 64/100
#  - 49s - loss: 1.6436 - acc: 0.4466 - val_loss: 1.6142 - val_acc: 0.4814
#
# Epoch 00064: val_loss did not improve from 0.92183
# Epoch 65/100
#  - 47s - loss: 1.6335 - acc: 0.4462 - val_loss: 1.7228 - val_acc: 0.3600
#
# Epoch 00065: val_loss did not improve from 0.92183
# Epoch 66/100
#  - 45s - loss: 1.6350 - acc: 0.4474 - val_loss: 1.5126 - val_acc: 0.4650
#
# Epoch 00066: val_loss did not improve from 0.92183
# Epoch 67/100
#  - 47s - loss: 1.6628 - acc: 0.4376 - val_loss: 1.5032 - val_acc: 0.4728
#
# Epoch 00067: val_loss did not improve from 0.92183
# Epoch 68/100
#  - 46s - loss: 1.6717 - acc: 0.4300 - val_loss: 2.0131 - val_acc: 0.4468
#
# Epoch 00068: val_loss did not improve from 0.92183
# Epoch 69/100
#  - 45s - loss: 1.6939 - acc: 0.4269 - val_loss: 2.4678 - val_acc: 0.3498
#
# Epoch 00069: val_loss did not improve from 0.92183
# Epoch 70/100
#  - 43s - loss: 1.6761 - acc: 0.4287 - val_loss: 1.4816 - val_acc: 0.4448
#
# Epoch 00070: val_loss did not improve from 0.92183
# Epoch 71/100
#  - 43s - loss: 1.6843 - acc: 0.4229 - val_loss: 1.6084 - val_acc: 0.4374
#
# Epoch 00071: val_loss did not improve from 0.92183
# Epoch 72/100
#  - 44s - loss: 1.7212 - acc: 0.4123 - val_loss: 3.5697 - val_acc: 0.3196
#
# Epoch 00072: val_loss did not improve from 0.92183
# Epoch 73/100
#  - 46s - loss: 1.7265 - acc: 0.4076 - val_loss: 1.5180 - val_acc: 0.4436
#
# Epoch 00073: val_loss did not improve from 0.92183
# Epoch 74/100
#  - 45s - loss: 1.7262 - acc: 0.4037 - val_loss: 1.5162 - val_acc: 0.4558
#
# Epoch 00074: val_loss did not improve from 0.92183
# Epoch 75/100
#  - 47s - loss: 1.7310 - acc: 0.4054 - val_loss: 1.3900 - val_acc: 0.5248
#
# Epoch 00075: val_loss did not improve from 0.92183
# Epoch 76/100
#  - 44s - loss: 1.7194 - acc: 0.4094 - val_loss: 1.5974 - val_acc: 0.4054
#
# Epoch 00076: val_loss did not improve from 0.92183
# Epoch 77/100
#  - 44s - loss: 1.7249 - acc: 0.4048 - val_loss: 2.2180 - val_acc: 0.4460
#
# Epoch 00077: val_loss did not improve from 0.92183
# Epoch 78/100
#  - 43s - loss: 1.7412 - acc: 0.4005 - val_loss: 1.5395 - val_acc: 0.4336
#
# Epoch 00078: val_loss did not improve from 0.92183
# Epoch 79/100
#  - 43s - loss: 1.7445 - acc: 0.4052 - val_loss: 1.5569 - val_acc: 0.4464
#
# Epoch 00079: val_loss did not improve from 0.92183
# Epoch 80/100
#  - 45s - loss: 1.7483 - acc: 0.4015 - val_loss: 1.5792 - val_acc: 0.4198
#
# Epoch 00080: val_loss did not improve from 0.92183
# Epoch 81/100
#  - 45s - loss: 1.7563 - acc: 0.3970 - val_loss: 2.6678 - val_acc: 0.4328
#
# Epoch 00081: val_loss did not improve from 0.92183
# Epoch 82/100
#  - 43s - loss: 1.7630 - acc: 0.3907 - val_loss: 2.3290 - val_acc: 0.3542
#
# Epoch 00082: val_loss did not improve from 0.92183
# Epoch 83/100
#  - 43s - loss: 1.7968 - acc: 0.3797 - val_loss: 1.5373 - val_acc: 0.4402
#
# Epoch 00083: val_loss did not improve from 0.92183
# Epoch 84/100
#  - 43s - loss: 1.7683 - acc: 0.3836 - val_loss: 1.6946 - val_acc: 0.4730
#
# Epoch 00084: val_loss did not improve from 0.92183
# Epoch 85/100
#  - 49s - loss: 1.7722 - acc: 0.3860 - val_loss: 1.4748 - val_acc: 0.4518
#
# Epoch 00085: val_loss did not improve from 0.92183
# Epoch 86/100
#  - 50s - loss: 1.7830 - acc: 0.3848 - val_loss: 1.7531 - val_acc: 0.4024
#
# Epoch 00086: val_loss did not improve from 0.92183
# Epoch 87/100
#  - 46s - loss: 1.8076 - acc: 0.3813 - val_loss: 1.8597 - val_acc: 0.2884
#
# Epoch 00087: val_loss did not improve from 0.92183
# Epoch 88/100
#  - 48s - loss: 1.7905 - acc: 0.3830 - val_loss: 2.8046 - val_acc: 0.3428
#
# Epoch 00088: val_loss did not improve from 0.92183
# Epoch 89/100
#  - 48s - loss: 1.8096 - acc: 0.3764 - val_loss: 1.7199 - val_acc: 0.3620
#
# Epoch 00089: val_loss did not improve from 0.92183
# Epoch 90/100
#  - 46s - loss: 1.8030 - acc: 0.3765 - val_loss: 1.5680 - val_acc: 0.4380
#
# Epoch 00090: val_loss did not improve from 0.92183
# Epoch 91/100
#  - 45s - loss: 1.8023 - acc: 0.3698 - val_loss: 2.7303 - val_acc: 0.3322
#
# Epoch 00091: val_loss did not improve from 0.92183
# Epoch 92/100
#  - 45s - loss: 1.8172 - acc: 0.3717 - val_loss: 1.5968 - val_acc: 0.4148
#
# Epoch 00092: val_loss did not improve from 0.92183
# Epoch 93/100
#  - 43s - loss: 1.8020 - acc: 0.3750 - val_loss: 1.6770 - val_acc: 0.3922
#
# Epoch 00093: val_loss did not improve from 0.92183
# Epoch 94/100
#  - 46s - loss: 1.8213 - acc: 0.3727 - val_loss: 1.6740 - val_acc: 0.3738
#
# Epoch 00094: val_loss did not improve from 0.92183
# Epoch 95/100
#  - 45s - loss: 1.8111 - acc: 0.3714 - val_loss: 1.4883 - val_acc: 0.4702
#
# Epoch 00095: val_loss did not improve from 0.92183
# Epoch 96/100
#  - 42s - loss: 1.8311 - acc: 0.3604 - val_loss: 1.4454 - val_acc: 0.4902
#
# Epoch 00096: val_loss did not improve from 0.92183
# Epoch 97/100
#  - 42s - loss: 1.8140 - acc: 0.3672 - val_loss: 1.6684 - val_acc: 0.4138
#
# Epoch 00097: val_loss did not improve from 0.92183
# Epoch 98/100
#  - 42s - loss: 1.8298 - acc: 0.3590 - val_loss: 1.6117 - val_acc: 0.4026
#
# Epoch 00098: val_loss did not improve from 0.92183
# Epoch 99/100
#  - 47s - loss: 1.8339 - acc: 0.3626 - val_loss: 2.7456 - val_acc: 0.3702
#
# Epoch 00099: val_loss did not improve from 0.92183
# Epoch 100/100
#  - 44s - loss: 1.8378 - acc: 0.3567 - val_loss: 1.7417 - val_acc: 0.3768
#
# Epoch 00100: val_loss did not improve from 0.92183

# %%
model.load_weights('CNN.weights.best.hdf5')

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('\n', 'Test Accuracy:', score[1])
# Out:
#  Test Accuracy: 0.6885

# %%
# get predictions on the test set
y_hat = model.predict(X_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(X_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(X_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
